# %%
import math
from sklearn.feature_extraction.text import TfidfVectorizer
import pandas as pd

# %%
df=pd.read_csv("..\DATA\EQUITY_L.csv")

# %%
df
# Out:
#           SYMBOL                           NAME OF COMPANY  SERIES  \
# 0      20MICRONS                        20 Microns Limited      EQ
# 1     21STCENMGM  21st Century Management Services Limited      BE
# 2         360ONE                       360 ONE WAM LIMITED      EQ
# 3      3IINFOLTD                       3i Infotech Limited      EQ
# 4        3MINDIA                          3M India Limited      EQ
# ...          ...                                       ...     ...
# 1966        ZOTA                  Zota Health Care LImited      EQ
# 1967       ZUARI              Zuari Agro Chemicals Limited      EQ
# 1968    ZUARIIND                  ZUARI INDUSTRIES LIMITED      EQ
# 1969   ZYDUSLIFE                Zydus Lifesciences Limited      EQ
# 1970   ZYDUSWELL                    Zydus Wellness Limited      EQ
#
#       DATE OF LISTING   PAID UP VALUE   MARKET LOT   ISIN NUMBER   FACE VALUE
# 0         06-OCT-2008               5            1  INE144J01027            5
# ...

# %%
df["search"].to_list()
# Out:
# ['20MICRONS - 20 Microns Limited',
#  '21STCENMGM - 21st Century Management Services Limited',
#  '360ONE - 360 ONE WAM LIMITED',
#  '3IINFOLTD - 3i Infotech Limited',
#  '3MINDIA - 3M India Limited',
#  '3PLAND - 3P Land Holdings Limited',
#  '5PAISA - 5Paisa Capital Limited',
#  '63MOONS - 63 moons technologies limited',
#  'A2ZINFRA - A2Z Infra Engineering Limited',
#  'AAATECH - AAA Technologies Limited',
#  'AADHARHFC - Aadhar Housing Finance Limited',
#  'AAKASH - Aakash Exploration Services Limited',
#  'AAREYDRUGS - Aarey Drugs & Pharmaceuticals Limited',
#  'AARON - Aaron Industries Limited',
#  'AARTECH - Aartech Solonics Limited',
#  'AARTIDRUGS - Aarti Drugs Limited',
#  'AARTIIND - Aarti Industries Limited',
#  'AARTIPHARM - Aarti Pharmalabs Limited',
#  'AARTISURF - Aarti Surfactants Limited',
#  'AARVEEDEN - Aarvee Denims & Exports Limited',
#  'AARVI - Aarvi Encon Limited',
#  'AAVAS - Aavas Financiers Limited',
#  'ABAN - Aban Offshore Limited',
# ...

# %%
df["search"]=df["SYMBOL"]+" - "+df["NAME OF COMPANY"]

# %%
Search_dictionary=dict()
for i in range(df.shape[0]):
    Search_dictionary[df['search'][i]]=df['SYMBOL'][i]

# %%
for i in Search_dictionary.keys():
    print(f'"{i}":"{Search_dictionary[i]}",')
# Out:
# "20MICRONS - 20 Microns Limited":"20MICRONS",
# "21STCENMGM - 21st Century Management Services Limited":"21STCENMGM",
# "360ONE - 360 ONE WAM LIMITED":"360ONE",
# "3IINFOLTD - 3i Infotech Limited":"3IINFOLTD",
# "3MINDIA - 3M India Limited":"3MINDIA",
# "3PLAND - 3P Land Holdings Limited":"3PLAND",
# "5PAISA - 5Paisa Capital Limited":"5PAISA",
# "63MOONS - 63 moons technologies limited":"63MOONS",
# "A2ZINFRA - A2Z Infra Engineering Limited":"A2ZINFRA",
# "AAATECH - AAA Technologies Limited":"AAATECH",
# "AADHARHFC - Aadhar Housing Finance Limited":"AADHARHFC",
# "AAKASH - Aakash Exploration Services Limited":"AAKASH",
# "AAREYDRUGS - Aarey Drugs & Pharmaceuticals Limited":"AAREYDRUGS",
# "AARON - Aaron Industries Limited":"AARON",
# "AARTECH - Aartech Solonics Limited":"AARTECH",
# "AARTIDRUGS - Aarti Drugs Limited":"AARTIDRUGS",
# "AARTIIND - Aarti Industries Limited":"AARTIIND",
# "AARTIPHARM - Aarti Pharmalabs Limited":"AARTIPHARM",
# ...
